# %% [markdown]
# # Bihar Part: 1

# %%
import pandas as pd # used for handling the dataset
import numpy as np #used for handling numbers/scientific computing
import matplotlib.pyplot as plt #used for plotting the datapoints
import seaborn as sb #used for statistical data visualization

# %% [markdown]
# # Data Preprocessing

# %%
# importing the dataset into 'raw_data' variable 
raw_data = pd.read_csv(r'F:\Sem_3\ML_Project\ahs-woman-1\AHS_Woman_10_Bihar\AHS_Woman_10_Bihar_Part_1.csv')
# Out:
# C:\Users\anike\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (14,118,147,178,185) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Printing the type of raw_data 
type(raw_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# 'shape' gives us the contents of dataset i.e., rows/entries/records/tuples = 866736
#                                                columns/features/attributes/variables = 202
raw_data.shape
# Out:
# (850683, 202)

# %%
# Names of the attributes in the dataset is
list(raw_data.columns)
# Out:
# ['w_id',
#  'hl_id',
#  'client_w_id',
#  'state',
#  'district',
#  'rural',
#  'stratum_code',
#  'psu_id',
#  'house_no',
#  'house_hold_no',
#  'year_of_intr',
#  'month_of_intr',
#  'date_of_intr',
#  'result_of_interview',
#  'other_int_code',
#  'serial_no',
#  'identifcation_code',
#  'age',
#  'marital_status',
#  'delivered_any_baby',
#  'born_alive_female',
#  'born_alive_male',
#  'born_alive_total',
#  'surviving_female',
#  'surviving_male',
#  'surviving_total',
#  'mother_age_when_baby_was_born',
#  'outcome_pregnancy',
#  'last_preg_no',
#  'previous_last_preg_no',
#  'second_last_preg_no',
#  'third_last_preg_no',
#  'w_expall_status',
#  'w_status',
#  'twsi_id',
#  'client_twsi_id',
#  'currently_widow',
#  'is_tubectomy',
#  'is_vasectomy',
#  'is_copper_t',
#  'is_pills_daily',
#  'is_piils_weekly',
#  'is_emergency_contraceptive',
#  'is_condom',
#  'is_moder_methods',
#  'is_contraceptive',
#  'is_periodic_abstinence',
#  'is_withdrawal',
#  'is_amenorrahoea',
#  'is_other_traditional_method',
#  'is_currently_pregnant',
#  'pregnant_month',
#  'is_anc_registered',
#  'willing_to_get_pregnant',
#  'is_currently_menstruating',
#  'when_you_bcome_mother_last_time',
#  'is_any_fp_methos_used',
#  'fp_method_used',
#  'source_of_treatment_for_fp',
#  'how_long_using_this_method',
#  'method_obtain_last_time',
#  'reason_for_not_using_fp_method',
#  'is_method_used_in_last_5_yrs',
#  'method_type_used_in_last_5_yrs',
#  'reason_for_discontinuation',
#  'intend_to_use_fp_method_in_futur',
#  'when_method_is_going_to_use',
#  'which_method_going_to_pefer_for_',
#  'want_more_childern',
#  'next_child_preference',
#  'time_for_next_child',
#  'anm_in_last_3_months',
#  'during_pregnancy',
#  'during_lactation',
#  'aware_abt_rti',
#  'aware_abt_hiv',
#  'aware_of_haf',
#  'aware_of_the_danger_signs',
#  'twsi_expall_status',
#  'fid',
#  'hh_id',
#  'client_hh_id',
#  'currently_dead_or_out_migrated',
#  'hh_serial_no',
#  'sex',
#  'usual_residance',
#  'relation_to_head',
#  'member_identity',
#  'father_serial_no',
#  'mother_serial_no',
#  'date_of_birth',
#  'month_of_birth',
#  'year_of_birth',
#  'religion',
#  'social_group_code',
#  'date_of_marriage',
#  'month_of_marriage',
#  'year_of_marriage',
#  'currently_attending_school',
#  'reason_for_not_attending_school',
#  'highest_qualification',
#  'occupation_status',
#  'disability_status',
#  'injury_treatment_type',
#  'illness_type',
#  'treatment_source',
#  'symptoms_pertaining_illness',
#  'sought_medical_care',
#  'diagnosed_for',
#  'diagnosis_source',
#  'regular_treatment',
#  'regular_treatment_source',
#  'chew',
#  'smoke',
#  'alcohol',
#  'status',
#  'hh_expall_status',
#  'client_hl_id',
#  'building_no',
#  'house_status',
#  'house_structure',
#  'owner_status',
#  'drinking_water_source',
#  'is_water_filter',
#  'water_filteration',
#  'toilet_used',
#  'is_toilet_shared',
#  'household_have_electricity',
#  'lighting_source',
#  'cooking_fuel',
#  'no_of_dwelling_rooms',
#  'kitchen_availability',
#  'is_radio',
#  'is_television',
#  'is_computer',
#  'is_telephone',
#  'is_washing_machine',
#  'is_refrigerator',
#  'is_sewing_machine',
#  'is_bicycle',
#  'is_scooter',
#  'is_car',
#  'is_tractor',
#  'is_water_pump',
#  'cart',
#  'land_possessed',
#  'hl_expall_status',
#  'sn',
#  'ever_conceived',
#  'no_of_times_conceived',
#  'age_at_first_conception',
#  'current_mar_status',
#  'is_injectable_contraceptive',
#  'months_of_preg_first_anc',
#  'is_husband_living_with_you',
#  'compensation_after_ster',
#  'received_compensation_after_ster',
#  'received_compensation_ster_rs',
#  'health_prob_afters_fp_use',
#  'counselled_for_menstrual_hyg',
#  'aware_abt_haf',
#  'aware_abt_ort_ors',
#  'aware_abt_ort_ors_zinc',
#  'aware_abt_danger_signs_new_born',
#  'new_born_alive_female',
#  'new_born_alive_male',
#  'new_born_alive_total',
#  'new_surviving_female',
#  'new_surviving_male',
#  'new_surviving_total',
#  'isdeadmigrated',
#  'residancial_status',
#  'iscoveredbyhealthscheme',
#  'healthscheme_1',
#  'healthscheme_2',
#  'housestatus',
#  'householdstatus',
#  'isheadchanged',
#  'headname',
#  'ever_born',
#  'wt',
#  'fidx',
#  'as',
#  'as_binned',
#  'fidh',
#  'cdoi',
#  'edt',
#  'occupation',
#  'catage1',
#  'marital',
#  'modern',
#  'traditional',
#  'anym',
#  'respondentname',
#  'rtelephoneno',
#  'isnewrecord',
#  'recordupdatedcount',
#  'recordstatus',
#  'schedule_id',
#  'year',
#  'id',
#  'v204']

# %%
# 'info' to get a concise summary of the dataframe
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850683 entries, 0 to 850682
# Columns: 202 entries, w_id to v204
# dtypes: float64(169), int64(28), object(5)
# memory usage: 1.3+ GB

# %%
# to view some basic statistical details like percentile, mean, std of dataframe(data)
raw_data.describe()
# Out:
#                 w_id          hl_id    client_w_id     state       district  \
# count  576004.000000  576004.000000  576004.000000  850683.0  850683.000000
# mean     8431.211769   12610.482361    1984.642584      10.0      15.685126
# std      5514.334696    8337.126993    2796.154339       0.0      10.147218
# min         1.000000       1.000000       1.000000      10.0       1.000000
# 25%      3918.000000    5834.000000     187.000000      10.0       6.000000
# 50%      7823.000000   11560.000000     727.000000      10.0      14.000000
# 75%     12155.000000   18220.000000    2792.000000      10.0      24.000000
# max     25895.000000   40376.000000   33367.000000      10.0      37.000000
#
#                rural   stratum_code        psu_id       house_no  \
# count  850683.000000  850683.000000  8.506830e+05  850683.000000
# mean        1.062904       1.683411  1.050863e+08     195.728903
# std         0.242790       0.584951  4.934545e+05     154.553140
# min         1.000000       0.000000  1.043937e+08       1.000000
# 25%         1.000000       1.000000  1.046696e+08      75.000000
# 50%         1.000000       2.000000  1.049664e+08     163.000000
# 75%         1.000000       2.000000  1.054815e+08     278.000000
# max         2.000000       2.000000  1.061111e+08    1018.000000
#
#        house_hold_no  ...  anym  respondentname  rtelephoneno  isnewrecord  \
# count  850683.000000  ...   0.0             0.0           0.0      23705.0
# mean        1.423473  ...   NaN             NaN           NaN          1.0
# std         0.885174  ...   NaN             NaN           NaN          0.0
# min         1.000000  ...   NaN             NaN           NaN          1.0
# 25%         1.000000  ...   NaN             NaN           NaN          1.0
# 50%         1.000000  ...   NaN             NaN           NaN          1.0
# 75%         2.000000  ...   NaN             NaN           NaN          1.0
# max        38.000000  ...   NaN             NaN           NaN          1.0
#
#        recordupdatedcount  recordstatus  schedule_id           year  \
# count       274679.000000      274679.0     850683.0  850683.000000
# mean             1.097219           2.0          2.0       1.379379
# std              0.374802           0.0          0.0       0.590274
# min              1.000000           2.0          2.0       1.000000
# 25%              1.000000           2.0          2.0       1.000000
# 50%              1.000000           2.0          2.0       1.000000
# 75%              1.000000           2.0          2.0       2.000000
# max             11.000000           2.0          2.0       3.000000
#
#                  id  v204
# count  8.506830e+05   0.0
# mean   5.806812e+05   NaN
# std    6.172030e+05   NaN
# min    1.000000e+00   NaN
# 25%    2.126715e+05   NaN
# 50%    4.253420e+05   NaN
# 75%    6.380125e+05   NaN
# max    2.947215e+06   NaN
#
# [8 rows x 197 columns]

# %% [markdown]
# # 1.Data Wrangling
# * Preprocessing On Columns(data_cols)
# * Preprocessing On Rows(data_rows)
# * Dropping Uncessary Features
# * Resetting the Indexes
# * Rearranging the Columns

# %%
#Selecting the features that are needed
data_cols = raw_data[['mother_age_when_baby_was_born','outcome_pregnancy','fp_method_used','symptoms_pertaining_illness','diagnosed_for','regular_treatment','chew','smoke','alcohol','drinking_water_source','kitchen_availability','is_washing_machine','is_bicycle','is_scooter','is_sewing_machine','ever_conceived','no_of_times_conceived','age_at_first_conception','delivered_any_baby']]

# %%
# 'shape' gives us the contents of dataset i.e., rows/entries/records/tuples = 1048575 
#                                                columns/features/attributes/variables = 19
data_cols.shape
# Out:
# (850683, 19)

# %%
# 'info' to get a concise summary of the dataframe
data_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850683 entries, 0 to 850682
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   mother_age_when_baby_was_born  720597 non-null  float64
#  1   outcome_pregnancy              760108 non-null  float64
#  2   fp_method_used                 286800 non-null  float64
#  3   symptoms_pertaining_illness    850683 non-null  int64
#  4   diagnosed_for                  850683 non-null  int64
#  5   regular_treatment              115224 non-null  float64
#  6   chew                           822505 non-null  float64
#  7   smoke                          822505 non-null  float64
#  8   alcohol                        822505 non-null  float64
#  9   drinking_water_source          832514 non-null  float64
#  10  kitchen_availability           832514 non-null  float64
#  11  is_washing_machine             832514 non-null  float64
#  12  is_bicycle                     832514 non-null  float64
#  13  is_scooter                     832514 non-null  float64
#  14  is_sewing_machine              832514 non-null  float64
#  15  ever_conceived                 259310 non-null  float64
#  16  no_of_times_conceived          246455 non-null  float64
#  17  age_at_first_conception        246455 non-null  float64
#  18  delivered_any_baby             760108 non-null  float64
# dtypes: float64(17), int64(2)
# memory usage: 123.3 MB

# %%
# to view some basic statistical details like percentile, mean, std of dataframe(data)
data_cols.describe()
# Out:
#        mother_age_when_baby_was_born  outcome_pregnancy  fp_method_used  \
# count                  720597.000000      760108.000000   286800.000000
# mean                       19.765837           1.707853        2.453250
# std                         5.027684           0.460816        3.132558
# min                         0.000000           0.000000        1.000000
# 25%                        18.000000           1.000000        1.000000
# 50%                        20.000000           2.000000        1.000000
# 75%                        22.000000           2.000000        1.000000
# max                        50.000000           2.000000       14.000000
#
#        symptoms_pertaining_illness  diagnosed_for  regular_treatment  \
# count                850683.000000  850683.000000      115224.000000
# mean                     33.722300       2.922473           1.672403
# std                      39.616211      11.549601           0.639253
# min                       1.000000       0.000000           1.000000
# 25%                      11.000000       0.000000           1.000000
# 50%                      11.000000       0.000000           2.000000
# 75%                      99.000000       0.000000           2.000000
# max                      99.000000      99.000000           3.000000
#
#                 chew         smoke        alcohol  drinking_water_source  \
# count  822505.000000  822505.00000  822505.000000          832514.000000
# mean        6.875696       3.94414       3.983716               3.069025
# std         0.712514       0.39047       0.202662               0.746681
# min         0.000000       0.00000       0.000000               1.000000
# 25%         7.000000       4.00000       4.000000               3.000000
# 50%         7.000000       4.00000       4.000000               3.000000
# 75%         7.000000       4.00000       4.000000               3.000000
# max         7.000000       4.00000       4.000000               9.000000
#
#        kitchen_availability  is_washing_machine     is_bicycle     is_scooter  \
# count         832514.000000       832514.000000  832514.000000  832514.000000
# mean               2.133474            1.991872       1.523407       1.928788
# std                0.906771            0.089790       0.499452       0.257179
# min                1.000000            1.000000       1.000000       1.000000
# 25%                2.000000            2.000000       1.000000       2.000000
# 50%                2.000000            2.000000       2.000000       2.000000
# 75%                3.000000            2.000000       2.000000       2.000000
# max                5.000000            2.000000       2.000000       2.000000
#
#        is_sewing_machine  ever_conceived  no_of_times_conceived  \
# count      832514.000000   259310.000000          246455.000000
# mean            1.918171        1.049574               3.560062
# std             0.274105        0.217063               1.910588
# min             1.000000        1.000000               1.000000
# 25%             2.000000        1.000000               2.000000
# 50%             2.000000        1.000000               3.000000
# 75%             2.000000        1.000000               5.000000
# max             2.000000        2.000000              16.000000
#
#        age_at_first_conception  delivered_any_baby
# count            246455.000000       760108.000000
# mean                 19.696427            1.079257
# std                   3.254292            0.280232
# min                  11.000000            0.000000
# 25%                  18.000000            1.000000
# 50%                  19.000000            1.000000
# 75%                  21.000000            1.000000
# max                  49.000000            2.000000

# %%
# 'isnull' detects the missing values and 'sum' returns the total count of null tuples for each attribute/column
data_cols.isnull().sum()
# Out:
# mother_age_when_baby_was_born    130086
# outcome_pregnancy                 90575
# fp_method_used                   563883
# symptoms_pertaining_illness           0
# diagnosed_for                         0
# regular_treatment                735459
# chew                              28178
# smoke                             28178
# alcohol                           28178
# drinking_water_source             18169
# kitchen_availability              18169
# is_washing_machine                18169
# is_bicycle                        18169
# is_scooter                        18169
# is_sewing_machine                 18169
# ever_conceived                   591373
# no_of_times_conceived            604228
# age_at_first_conception          604228
# delivered_any_baby                90575
# dtype: int64

# %%
data_cols.shape
# Out:
# (850683, 19)

# %%
# removing missing values from dataset(axis = 0 states for rows and 'any' states for any NA attribute in dataset)
data_rows = data_cols.dropna(how='any',axis=0)

# %%
data_rows.drop_duplicates()

# %%
data_rows.shape
# Out:
# (16086, 19)

# %%
data_rows.isnull().sum()
# Out:
# mother_age_when_baby_was_born    0
# outcome_pregnancy                0
# fp_method_used                   0
# symptoms_pertaining_illness      0
# diagnosed_for                    0
# regular_treatment                0
# chew                             0
# smoke                            0
# alcohol                          0
# drinking_water_source            0
# kitchen_availability             0
# is_washing_machine               0
# is_bicycle                       0
# is_scooter                       0
# is_sewing_machine                0
# ever_conceived                   0
# no_of_times_conceived            0
# age_at_first_conception          0
# delivered_any_baby               0
# dtype: int64

# %%
# Resetting the indexes
data_rows.reset_index(drop=True)
# Out:
#        mother_age_when_baby_was_born  outcome_pregnancy  fp_method_used  \
# 0                               15.0                2.0             1.0
# 1                               23.0                2.0             1.0
# 2                               21.0                2.0             1.0
# 3                               21.0                2.0             1.0
# 4                               18.0                2.0             1.0
# ...                              ...                ...             ...
# 16081                           22.0                2.0             1.0
# 16082                           20.0                2.0             1.0
# 16083                           33.0                2.0            11.0
# 16084                           18.0                2.0             1.0
# 16085                           17.0                1.0             1.0
#
#        symptoms_pertaining_illness  diagnosed_for  regular_treatment  chew  \
# 0                               99             19                2.0   7.0
# 1                                2              2                1.0   7.0
# 2                                6             99                1.0   7.0
# 3                               99              3                2.0   7.0
# 4                               99             19                1.0   7.0
# ...                            ...            ...                ...   ...
# 16081                            4             19                1.0   7.0
# 16082                           99              2                2.0   7.0
# 16083                            1             10                2.0   7.0
# 16084                           99              3                2.0   7.0
# 16085                           99             17                2.0   7.0
#
#        smoke  alcohol  drinking_water_source  kitchen_availability  \
# 0        4.0      4.0                    3.0                   2.0
# 1        4.0      1.0                    3.0                   2.0
# 2        4.0      4.0                    3.0                   3.0
# 3        4.0      4.0                    3.0                   2.0
# 4        4.0      4.0                    3.0                   2.0
# ...      ...      ...                    ...                   ...
# 16081    4.0      2.0                    3.0                   4.0
# 16082    4.0      4.0                    3.0                   4.0
# 16083    4.0      4.0                    3.0                   2.0
# 16084    4.0      4.0                    3.0                   4.0
# 16085    4.0      4.0                    3.0                   2.0
#
#        is_washing_machine  is_bicycle  is_scooter  is_sewing_machine  \
# 0                     2.0         1.0         2.0                2.0
# 1                     2.0         2.0         2.0                2.0
# 2                     2.0         2.0         2.0                2.0
# 3                     2.0         1.0         2.0                2.0
# 4                     2.0         2.0         2.0                2.0
# ...                   ...         ...         ...                ...
# 16081                 2.0         1.0         2.0                2.0
# 16082                 2.0         1.0         2.0                2.0
# 16083                 2.0         1.0         2.0                2.0
# 16084                 2.0         1.0         2.0                2.0
# 16085                 2.0         1.0         2.0                2.0
#
#        ever_conceived  no_of_times_conceived  age_at_first_conception  \
# 0                 1.0                    1.0                     15.0
# 1                 1.0                    3.0                     22.0
# 2                 1.0                    3.0                     20.0
# 3                 1.0                    6.0                     21.0
# 4                 1.0                    3.0                     17.0
# ...               ...                    ...                      ...
# 16081             1.0                    5.0                     22.0
# 16082             1.0                    6.0                     20.0
# 16083             1.0                    4.0                     33.0
# 16084             1.0                    4.0                     17.0
# 16085             1.0                    5.0                     17.0
#
#        delivered_any_baby
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3                     1.0
# 4                     1.0
# ...                   ...
# 16081                 1.0
# 16082                 1.0
# 16083                 1.0
# 16084                 1.0
# 16085                 1.0
#
# [16086 rows x 19 columns]

# %%
data_rows.shape
# Out:
# (16086, 19)

# %%
data_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16086 entries, 1000 to 850641
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mother_age_when_baby_was_born  16086 non-null  float64
#  1   outcome_pregnancy              16086 non-null  float64
#  2   fp_method_used                 16086 non-null  float64
#  3   symptoms_pertaining_illness    16086 non-null  int64
#  4   diagnosed_for                  16086 non-null  int64
#  5   regular_treatment              16086 non-null  float64
#  6   chew                           16086 non-null  float64
#  7   smoke                          16086 non-null  float64
#  8   alcohol                        16086 non-null  float64
#  9   drinking_water_source          16086 non-null  float64
#  10  kitchen_availability           16086 non-null  float64
#  11  is_washing_machine             16086 non-null  float64
#  12  is_bicycle                     16086 non-null  float64
#  13  is_scooter                     16086 non-null  float64
#  14  is_sewing_machine              16086 non-null  float64
#  15  ever_conceived                 16086 non-null  float64
#  16  no_of_times_conceived          16086 non-null  float64
#  17  age_at_first_conception        16086 non-null  float64
#  18  delivered_any_baby             16086 non-null  float64
# dtypes: float64(17), int64(2)
# memory usage: 2.5 MB

# %%
data_rows.describe()
# Out:
#        mother_age_when_baby_was_born  outcome_pregnancy  fp_method_used  \
# count                   16086.000000       16086.000000    16086.000000
# mean                       20.566393           1.951262        2.519209
# std                         3.440860           0.215327        3.245806
# min                        13.000000           1.000000        1.000000
# 25%                        18.000000           2.000000        1.000000
# 50%                        20.000000           2.000000        1.000000
# 75%                        22.000000           2.000000        1.000000
# max                        40.000000           2.000000       14.000000
#
#        symptoms_pertaining_illness  diagnosed_for  regular_treatment  \
# count                 16086.000000   16086.000000       16086.000000
# mean                     41.920055      31.399975           1.675556
# std                      45.890449      36.308828           0.612670
# min                       1.000000       1.000000           1.000000
# 25%                       4.000000       7.000000           1.000000
# 50%                       7.000000      18.000000           2.000000
# 75%                      99.000000      29.000000           2.000000
# max                      99.000000      99.000000           3.000000
#
#                chew         smoke       alcohol  drinking_water_source  \
# count  16086.000000  16086.000000  16086.000000           16086.000000
# mean       6.832587      3.902275      3.984583               2.990986
# std        0.826141      0.515617      0.202897               0.551015
# min        0.000000      0.000000      0.000000               1.000000
# 25%        7.000000      4.000000      4.000000               3.000000
# 50%        7.000000      4.000000      4.000000               3.000000
# 75%        7.000000      4.000000      4.000000               3.000000
# max        7.000000      4.000000      4.000000               9.000000
#
#        kitchen_availability  is_washing_machine    is_bicycle    is_scooter  \
# count          16086.000000        16086.000000  16086.000000  16086.000000
# mean               2.176986            1.992789      1.419557      1.924904
# std                0.955039            0.084615      0.493502      0.263555
# min                1.000000            1.000000      1.000000      1.000000
# 25%                1.000000            2.000000      1.000000      2.000000
# 50%                2.000000            2.000000      1.000000      2.000000
# 75%                3.000000            2.000000      2.000000      2.000000
# max                5.000000            2.000000      2.000000      2.000000
#
#        is_sewing_machine  ever_conceived  no_of_times_conceived  \
# count       16086.000000         16086.0           16086.000000
# mean            1.929131             1.0               4.124767
# std             0.256614             0.0               1.687906
# min             1.000000             1.0               1.000000
# 25%             2.000000             1.0               3.000000
# 50%             2.000000             1.0               4.000000
# 75%             2.000000             1.0               5.000000
# max             2.000000             1.0              15.000000
#
#        age_at_first_conception  delivered_any_baby
# count             16086.000000             16086.0
# mean                 19.260040                 1.0
# std                   3.256206                 0.0
# min                  13.000000                 1.0
# 25%                  17.000000                 1.0
# 50%                  19.000000                 1.0
# 75%                  21.000000                 1.0
# max                  40.000000                 1.0

# %%
df1 = data_rows.drop('outcome_pregnancy', axis = 1)

# %%
df1.reset_index(drop=True)
# Out:
#        mother_age_when_baby_was_born  fp_method_used  \
# 0                               15.0             1.0
# 1                               23.0             1.0
# 2                               21.0             1.0
# 3                               21.0             1.0
# 4                               18.0             1.0
# ...                              ...             ...
# 16081                           22.0             1.0
# 16082                           20.0             1.0
# 16083                           33.0            11.0
# 16084                           18.0             1.0
# 16085                           17.0             1.0
#
#        symptoms_pertaining_illness  diagnosed_for  regular_treatment  chew  \
# 0                               99             19                2.0   7.0
# 1                                2              2                1.0   7.0
# 2                                6             99                1.0   7.0
# 3                               99              3                2.0   7.0
# 4                               99             19                1.0   7.0
# ...                            ...            ...                ...   ...
# 16081                            4             19                1.0   7.0
# 16082                           99              2                2.0   7.0
# 16083                            1             10                2.0   7.0
# 16084                           99              3                2.0   7.0
# 16085                           99             17                2.0   7.0
#
#        smoke  alcohol  drinking_water_source  kitchen_availability  \
# 0        4.0      4.0                    3.0                   2.0
# 1        4.0      1.0                    3.0                   2.0
# 2        4.0      4.0                    3.0                   3.0
# 3        4.0      4.0                    3.0                   2.0
# 4        4.0      4.0                    3.0                   2.0
# ...      ...      ...                    ...                   ...
# 16081    4.0      2.0                    3.0                   4.0
# 16082    4.0      4.0                    3.0                   4.0
# 16083    4.0      4.0                    3.0                   2.0
# 16084    4.0      4.0                    3.0                   4.0
# 16085    4.0      4.0                    3.0                   2.0
#
#        is_washing_machine  is_bicycle  is_scooter  is_sewing_machine  \
# 0                     2.0         1.0         2.0                2.0
# 1                     2.0         2.0         2.0                2.0
# 2                     2.0         2.0         2.0                2.0
# 3                     2.0         1.0         2.0                2.0
# 4                     2.0         2.0         2.0                2.0
# ...                   ...         ...         ...                ...
# 16081                 2.0         1.0         2.0                2.0
# 16082                 2.0         1.0         2.0                2.0
# 16083                 2.0         1.0         2.0                2.0
# 16084                 2.0         1.0         2.0                2.0
# 16085                 2.0         1.0         2.0                2.0
#
#        ever_conceived  no_of_times_conceived  age_at_first_conception  \
# 0                 1.0                    1.0                     15.0
# 1                 1.0                    3.0                     22.0
# 2                 1.0                    3.0                     20.0
# 3                 1.0                    6.0                     21.0
# 4                 1.0                    3.0                     17.0
# ...               ...                    ...                      ...
# 16081             1.0                    5.0                     22.0
# 16082             1.0                    6.0                     20.0
# 16083             1.0                    4.0                     33.0
# 16084             1.0                    4.0                     17.0
# 16085             1.0                    5.0                     17.0
#
#        delivered_any_baby
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3                     1.0
# 4                     1.0
# ...                   ...
# 16081                 1.0
# 16082                 1.0
# 16083                 1.0
# 16084                 1.0
# 16085                 1.0
#
# [16086 rows x 18 columns]

# %%
list(df1.columns)
# Out:
# ['mother_age_when_baby_was_born',
#  'fp_method_used',
#  'symptoms_pertaining_illness',
#  'diagnosed_for',
#  'regular_treatment',
#  'chew',
#  'smoke',
#  'alcohol',
#  'drinking_water_source',
#  'kitchen_availability',
#  'is_washing_machine',
#  'is_bicycle',
#  'is_scooter',
#  'is_sewing_machine',
#  'ever_conceived',
#  'no_of_times_conceived',
#  'age_at_first_conception',
#  'delivered_any_baby']

# %%
df1['outcome_pregnancy'] = pd.DataFrame(data_rows['outcome_pregnancy'])

# %%
list(df1.columns)
# Out:
# ['mother_age_when_baby_was_born',
#  'fp_method_used',
#  'symptoms_pertaining_illness',
#  'diagnosed_for',
#  'regular_treatment',
#  'chew',
#  'smoke',
#  'alcohol',
#  'drinking_water_source',
#  'kitchen_availability',
#  'is_washing_machine',
#  'is_bicycle',
#  'is_scooter',
#  'is_sewing_machine',
#  'ever_conceived',
#  'no_of_times_conceived',
#  'age_at_first_conception',
#  'delivered_any_baby',
#  'outcome_pregnancy']

# %%
pregnancy_details = df1

# %%
list(pregnancy_details.columns)
# Out:
# ['mother_age_when_baby_was_born',
#  'fp_method_used',
#  'symptoms_pertaining_illness',
#  'diagnosed_for',
#  'regular_treatment',
#  'chew',
#  'smoke',
#  'alcohol',
#  'drinking_water_source',
#  'kitchen_availability',
#  'is_washing_machine',
#  'is_bicycle',
#  'is_scooter',
#  'is_sewing_machine',
#  'ever_conceived',
#  'no_of_times_conceived',
#  'age_at_first_conception',
#  'delivered_any_baby',
#  'outcome_pregnancy']

# %%
pregnancy_details.head()
# Out:
#       mother_age_when_baby_was_born  fp_method_used  \
# 1000                           15.0             1.0
# 1007                           23.0             1.0
# 1008                           21.0             1.0
# 1027                           21.0             1.0
# 1041                           18.0             1.0
#
#       symptoms_pertaining_illness  diagnosed_for  regular_treatment  chew  \
# 1000                           99             19                2.0   7.0
# 1007                            2              2                1.0   7.0
# 1008                            6             99                1.0   7.0
# 1027                           99              3                2.0   7.0
# 1041                           99             19                1.0   7.0
#
#       smoke  alcohol  drinking_water_source  kitchen_availability  \
# 1000    4.0      4.0                    3.0                   2.0
# 1007    4.0      1.0                    3.0                   2.0
# 1008    4.0      4.0                    3.0                   3.0
# 1027    4.0      4.0                    3.0                   2.0
# 1041    4.0      4.0                    3.0                   2.0
#
#       is_washing_machine  is_bicycle  is_scooter  is_sewing_machine  \
# 1000                 2.0         1.0         2.0                2.0
# 1007                 2.0         2.0         2.0                2.0
# 1008                 2.0         2.0         2.0                2.0
# 1027                 2.0         1.0         2.0                2.0
# 1041                 2.0         2.0         2.0                2.0
#
#       ever_conceived  no_of_times_conceived  age_at_first_conception  \
# 1000             1.0                    1.0                     15.0
# 1007             1.0                    3.0                     22.0
# 1008             1.0                    3.0                     20.0
# 1027             1.0                    6.0                     21.0
# 1041             1.0                    3.0                     17.0
#
#       delivered_any_baby  outcome_pregnancy
# 1000                 1.0                2.0
# 1007                 1.0                2.0
# 1008                 1.0                2.0
# 1027                 1.0                2.0
# 1041                 1.0                2.0

# %%
pregnancy_details.isnull().sum()
# Out:
# mother_age_when_baby_was_born    0
# fp_method_used                   0
# symptoms_pertaining_illness      0
# diagnosed_for                    0
# regular_treatment                0
# chew                             0
# smoke                            0
# alcohol                          0
# drinking_water_source            0
# kitchen_availability             0
# is_washing_machine               0
# is_bicycle                       0
# is_scooter                       0
# is_sewing_machine                0
# ever_conceived                   0
# no_of_times_conceived            0
# age_at_first_conception          0
# delivered_any_baby               0
# outcome_pregnancy                0
# dtype: int64

# %%
pregnancy_details.shape
# Out:
# (16086, 19)

# %%
pregnancy_details = pregnancy_details.astype(np.int64)

# %%
pregnancy_details = pregnancy_details.reset_index(drop=True)

# %%
pregnancy_details.shape
# Out:
# (16086, 19)

# %%
pregnancy_details.head()
# Out:
#    mother_age_when_baby_was_born  fp_method_used  symptoms_pertaining_illness  \
# 0                             15               1                           99
# 1                             23               1                            2
# 2                             21               1                            6
# 3                             21               1                           99
# 4                             18               1                           99
#
#    diagnosed_for  regular_treatment  chew  smoke  alcohol  \
# 0             19                  2     7      4        4
# 1              2                  1     7      4        1
# 2             99                  1     7      4        4
# 3              3                  2     7      4        4
# 4             19                  1     7      4        4
#
#    drinking_water_source  kitchen_availability  is_washing_machine  \
# 0                      3                     2                   2
# 1                      3                     2                   2
# 2                      3                     3                   2
# 3                      3                     2                   2
# 4                      3                     2                   2
#
#    is_bicycle  is_scooter  is_sewing_machine  ever_conceived  \
# 0           1           2                  2               1
# 1           2           2                  2               1
# 2           2           2                  2               1
# 3           1           2                  2               1
# 4           2           2                  2               1
#
#    no_of_times_conceived  age_at_first_conception  delivered_any_baby  \
# 0                      1                       15                   1
# 1                      3                       22                   1
# 2                      3                       20                   1
# 3                      6                       21                   1
# 4                      3                       17                   1
#
#    outcome_pregnancy
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2

# %%
#Saving the output(without indexes) of dataframe(data_rows) to csv file named as "pregnancy_details"
#pregnancy_details.to_csv(r'F:\Sem_3\ML_Project\preg\Cleaned_Data\Bihar_Part2_Cleaned.csv',index = False)

# %% [markdown]
#    # 2. Correlations for the Pregnancy Details

# %%
def corr_matrix():
        
    # For computing pairwise correlation of columns, excluding NA/null values
    correlation = pregnancy_details.corr(method='pearson')
    correlation
    f = plt.figure(figsize=(10, 10))
    plt.matshow(pregnancy_details.corr(), fignum=f.number)
    plt.xticks(range(pregnancy_details.shape[1]), pregnancy_details.columns, fontsize=14, rotation=90)
    plt.yticks(range(pregnancy_details.shape[1]), pregnancy_details.columns, fontsize=14)
    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    #plt.title('Correlation Matrix', fontsize=16);
    plt.savefig(r'F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\1.png')
    return correlation
corr_matrix()
# Out:
#                                mother_age_when_baby_was_born  fp_method_used  \
# mother_age_when_baby_was_born                       1.000000        0.033848
# fp_method_used                                      0.033848        1.000000
# symptoms_pertaining_illness                         0.005917       -0.071710
# diagnosed_for                                       0.009749        0.163807
# regular_treatment                                  -0.002477       -0.028520
# chew                                                0.005540       -0.006834
# smoke                                              -0.002895        0.015312
# alcohol                                             0.002179        0.008757
# drinking_water_source                               0.013055       -0.067287
# kitchen_availability                               -0.029845       -0.079444
# is_washing_machine                                  0.001858        0.012502
# is_bicycle                                          0.012903        0.016140
# is_scooter                                          0.011257        0.022617
# is_sewing_machine                                   0.015750        0.015667
# ever_conceived                                           NaN             NaN
# no_of_times_conceived                               0.006115        0.007534
# age_at_first_conception                             0.843635        0.027312
# delivered_any_baby                                       NaN             NaN
# outcome_pregnancy                                  -0.018959       -0.171051
#
#                                symptoms_pertaining_illness  diagnosed_for  \
# mother_age_when_baby_was_born                     0.005917       0.009749
# fp_method_used                                   -0.071710       0.163807
# symptoms_pertaining_illness                       1.000000      -0.382201
# diagnosed_for                                    -0.382201       1.000000
# regular_treatment                                 0.017006      -0.073836
# chew                                             -0.047243       0.035537
# smoke                                            -0.018501       0.033582
# alcohol                                           0.024292      -0.010842
# drinking_water_source                             0.039691      -0.074544
# kitchen_availability                              0.001626      -0.032773
# is_washing_machine                               -0.022724      -0.005678
# is_bicycle                                       -0.012176      -0.011656
# is_scooter                                       -0.021042       0.003009
# is_sewing_machine                                -0.023272       0.011530
# ever_conceived                                         NaN            NaN
# no_of_times_conceived                            -0.043882      -0.007534
# age_at_first_conception                           0.006827       0.023619
# delivered_any_baby                                     NaN            NaN
# outcome_pregnancy                                 0.006174      -0.053130
#
#                                regular_treatment      chew     smoke  \
# mother_age_when_baby_was_born          -0.002477  0.005540 -0.002895
# fp_method_used                         -0.028520 -0.006834  0.015312
# symptoms_pertaining_illness             0.017006 -0.047243 -0.018501
# diagnosed_for                          -0.073836  0.035537  0.033582
# regular_treatment                       1.000000  0.011088  0.007867
# chew                                    0.011088  1.000000  0.122279
# smoke                                   0.007867  0.122279  1.000000
# alcohol                                -0.008233  0.103287  0.185268
# drinking_water_source                  -0.007190 -0.027079 -0.017543
# kitchen_availability                    0.023130 -0.022486 -0.025096
# is_washing_machine                     -0.015153 -0.014603 -0.000479
# is_bicycle                             -0.017957 -0.001088 -0.011106
# is_scooter                             -0.020378  0.001646 -0.032963
# is_sewing_machine                       0.000844 -0.006994 -0.011468
# ever_conceived                               NaN       NaN       NaN
# no_of_times_conceived                  -0.009609 -0.031298 -0.074924
# age_at_first_conception                -0.015390  0.012741  0.011545
# delivered_any_baby                           NaN       NaN       NaN
# outcome_pregnancy                      -0.008183 -0.017213 -0.016584
#
#                                 alcohol  drinking_water_source  \
# mother_age_when_baby_was_born  0.002179               0.013055
# fp_method_used                 0.008757              -0.067287
# symptoms_pertaining_illness    0.024292               0.039691
# diagnosed_for                 -0.010842              -0.074544
# regular_treatment             -0.008233              -0.007190
# chew                           0.103287              -0.027079
# smoke                          0.185268              -0.017543
# alcohol                        1.000000               0.014883
# drinking_water_source          0.014883               1.000000
# kitchen_availability           0.002853               0.082540
# is_washing_machine            -0.006476               0.002606
# is_bicycle                     0.001894               0.011851
# is_scooter                    -0.010026               0.004329
# is_sewing_machine              0.010059               0.008672
# ever_conceived                      NaN                    NaN
# no_of_times_conceived          0.007069               0.029819
# age_at_first_conception        0.004657               0.016379
# delivered_any_baby                  NaN                    NaN
# outcome_pregnancy              0.001299               0.017780
#
#                                kitchen_availability  is_washing_machine  \
# mother_age_when_baby_was_born             -0.029845            0.001858
# fp_method_used                            -0.079444            0.012502
# symptoms_pertaining_illness                0.001626           -0.022724
# diagnosed_for                             -0.032773           -0.005678
# regular_treatment                          0.023130           -0.015153
# chew                                      -0.022486           -0.014603
# smoke                                     -0.025096           -0.000479
# alcohol                                    0.002853           -0.006476
# drinking_water_source                      0.082540            0.002606
# kitchen_availability                       1.000000            0.063493
# is_washing_machine                         0.063493            1.000000
# is_bicycle                                 0.044389           -0.001982
# is_scooter                                 0.080224            0.170861
# is_sewing_machine                          0.071477            0.191202
# ever_conceived                                  NaN                 NaN
# no_of_times_conceived                      0.051632            0.033288
# age_at_first_conception                   -0.021118           -0.010568
# delivered_any_baby                              NaN                 NaN
# outcome_pregnancy                         -0.008841           -0.019291
#
#                                is_bicycle  is_scooter  is_sewing_machine  \
# mother_age_when_baby_was_born    0.012903    0.011257           0.015750
# fp_method_used                   0.016140    0.022617           0.015667
# symptoms_pertaining_illness     -0.012176   -0.021042          -0.023272
# diagnosed_for                   -0.011656    0.003009           0.011530
# regular_treatment               -0.017957   -0.020378           0.000844
# chew                            -0.001088    0.001646          -0.006994
# smoke                           -0.011106   -0.032963          -0.011468
# alcohol                          0.001894   -0.010026           0.010059
# drinking_water_source            0.011851    0.004329           0.008672
# kitchen_availability             0.044389    0.080224           0.071477
# is_washing_machine              -0.001982    0.170861           0.191202
# is_bicycle                       1.000000    0.073527           0.063474
# is_scooter                       0.073527    1.000000           0.216379
# is_sewing_machine                0.063474    0.216379           1.000000
# ever_conceived                        NaN         NaN                NaN
# no_of_times_conceived            0.016192    0.091219           0.072230
# age_at_first_conception          0.014430    0.008268           0.001670
# delivered_any_baby                    NaN         NaN                NaN
# outcome_pregnancy               -0.029877   -0.026156          -0.025384
#
#                                ever_conceived  no_of_times_conceived  \
# mother_age_when_baby_was_born             NaN               0.006115
# fp_method_used                            NaN               0.007534
# symptoms_pertaining_illness               NaN              -0.043882
# diagnosed_for                             NaN              -0.007534
# regular_treatment                         NaN              -0.009609
# chew                                      NaN              -0.031298
# smoke                                     NaN              -0.074924
# alcohol                                   NaN               0.007069
# drinking_water_source                     NaN               0.029819
# kitchen_availability                      NaN               0.051632
# is_washing_machine                        NaN               0.033288
# is_bicycle                                NaN               0.016192
# is_scooter                                NaN               0.091219
# is_sewing_machine                         NaN               0.072230
# ever_conceived                            NaN                    NaN
# no_of_times_conceived                     NaN               1.000000
# age_at_first_conception                   NaN              -0.091441
# delivered_any_baby                        NaN                    NaN
# outcome_pregnancy                         NaN               0.017245
#
#                                age_at_first_conception  delivered_any_baby  \
# mother_age_when_baby_was_born                 0.843635                 NaN
# fp_method_used                                0.027312                 NaN
# symptoms_pertaining_illness                   0.006827                 NaN
# diagnosed_for                                 0.023619                 NaN
# regular_treatment                            -0.015390                 NaN
# chew                                          0.012741                 NaN
# smoke                                         0.011545                 NaN
# alcohol                                       0.004657                 NaN
# drinking_water_source                         0.016379                 NaN
# kitchen_availability                         -0.021118                 NaN
# is_washing_machine                           -0.010568                 NaN
# is_bicycle                                    0.014430                 NaN
# is_scooter                                    0.008268                 NaN
# is_sewing_machine                             0.001670                 NaN
# ever_conceived                                     NaN                 NaN
# no_of_times_conceived                        -0.091441                 NaN
# age_at_first_conception                       1.000000                 NaN
# delivered_any_baby                                 NaN                 NaN
# outcome_pregnancy                            -0.035745                 NaN
#
#                                outcome_pregnancy
# mother_age_when_baby_was_born          -0.018959
# fp_method_used                         -0.171051
# symptoms_pertaining_illness             0.006174
# diagnosed_for                          -0.053130
# regular_treatment                      -0.008183
# chew                                   -0.017213
# smoke                                  -0.016584
# alcohol                                 0.001299
# drinking_water_source                   0.017780
# kitchen_availability                   -0.008841
# is_washing_machine                     -0.019291
# is_bicycle                             -0.029877
# is_scooter                             -0.026156
# is_sewing_machine                      -0.025384
# ever_conceived                               NaN
# no_of_times_conceived                   0.017245
# age_at_first_conception                -0.035745
# delivered_any_baby                           NaN
# outcome_pregnancy                       1.000000

# %% [markdown]
# # 3. Exploratory Data Analysis
# * Pairplots
# * Boxplots
# * Barplots
# * Violinplots

# %%
import seaborn as sb
class EDA():
    
    def pairplots():
        sb.pairplot(pregnancy_details)
        sb.set_style('darkgrid')

    def boxplots():
         for c in pregnancy_details.columns[1:]:
            pregnancy_details.boxplot(c,by='outcome_pregnancy',figsize=(8,4),fontsize=14,grid=True)
            plt.title("{}\n".format(c),fontsize=16)
            plt.xlabel("Pregnancy Outcome", fontsize=16)
            plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\box.png")

    def count_barplots():
        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='chew',data=pregnancy_details)
        plt.title("Bar chart of outcome of pregnancy compared to consumption of tobacco", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(['Pan with tobacco','Pan without tobacco','Gutka/Pan masala with tobacco','Gutka/Pan masala without tobacco','Tobacco only','Ex–Chewer','Never chewed','Not known'],loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\1.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='drinking_water_source',data=pregnancy_details,orient='v')
        plt.title("Bar chart of outcome of pregnancy compared to source of drinking water", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(['Piped water into dwelling/yard/plot','Public tap/standpipe','Hand pump', 'Tube well or Borehole', 'Protected dug well', 'Unprotected dug well', 'Tanker /truck/Cart with Surface watersmall tank', 'Surface water', 'other sources'],loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\2.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='kitchen_availability',data=pregnancy_details)
        plt.title("Bar chart of outcome of pregnancy compared to availability of kitchen", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(['Cooking inside the house:Has kitchen','Does not have kitchen','Cooking outside house:Has kitchen','Does not have kitchen','No cooking'], loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\3.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='regular_treatment',data=pregnancy_details)
        plt.title("Bar chart of outcome of pregnancy compared to the treament taken", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(['Not Regularly','Regularly','No Treatment'], loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\4.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='no_of_times_conceived',data=pregnancy_details)
        plt.title("Bar chart of outcome of pregnancy compared to the number of times conceived", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\5.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='is_sewing_machine',data=pregnancy_details)
        plt.title("Bar chart of outcome of pregnancy compared to use of sewing machine", fontsize=17)
        plt.xlabel("Count", fontsize=15)
        plt.ylabel("Outcome Of Pregnancy", fontsize=15)
        plt.legend(['Uses Sewing Machine','Does not use Sewing Machine'],loc=1)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\6.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='mother_age_when_baby_was_born',data=pregnancy_details)
        plt.xlabel('Count',fontsize=15)
        plt.ylabel('Outcome Of Pregnancy',fontsize=15)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\7.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='symptoms_pertaining_illness',data=pregnancy_details)
        plt.xlabel('Count',fontsize=15)
        plt.ylabel('Outcome Of Pregnancy',fontsize=15)
        plt.legend(['Diseases of respiratory system','Diseases of cardiovascular system','Diseases of the central nervous  system','Diseases of   musculo-skeletal system','Diseases of gastrointestinal system','Diseases of genito urinary system','Skin diseases','Goitre','Elephantiasis','Others','Asymptomatic','Eye Problem/diseases','ENT problems/diseases','Mouth and Dental Problems','Others','No Symptoms of chronic diseases'])
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\8.png")
        
        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='is_scooter',data=pregnancy_details)
        plt.xlabel('Count',fontsize=15)
        plt.ylabel('Outcome Of Pregnancy',fontsize=15)
        plt.legend(['Uses Scooter','Does not use Scooter'])
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\9.png")
        
        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='is_bicycle',data=pregnancy_details)
        plt.xlabel('Count',fontsize=15)
        plt.ylabel('Outcome Of Pregnancy',fontsize=15)
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\10.png")

        plt.figure(figsize=(13,6))
        sb.set_style('darkgrid')
        sb.countplot(y='outcome_pregnancy',hue='diagnosed_for',data=pregnancy_details)
        plt.xlabel('Count',fontsize=15)
        plt.ylabel('Outcome Of Pregnancy',fontsize=15)
        plt.legend()
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\11.png")
        
    def violinplots():
        sb.catplot(x="fp_method_used",y="outcome_pregnancy",legend=True,data=pregnancy_details,kind="violin")
        
        sb.catplot(x="symptoms_pertaining_illness",y="outcome_pregnancy",legend=True,data=pregnancy_details,kind="violin")
        
        sb.catplot(x="regular_treatment",y="outcome_pregnancy",legend=True,data=pregnancy_details,kind="violin")
        
        sb.catplot(x="kitchen_availability",y="outcome_pregnancy",legend=True,data=pregnancy_details,kind="violin")

# %%
EDA.pairplots()

# %%
EDA.boxplots()

# %%
EDA.count_barplots()

# %%
EDA.violinplots()

# %% [markdown]
# # Modelling and Algorithms

# %%
#importing libraries
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Accuracy Score
# * Classification Accuracy is what we usually mean, when we use the term accuracy. It is the ratio of number of correct predictions to the total number of input samples.

# %%
# for Printing accuracy classification score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Confusion Matrix
# * Confusion Matrix as the name suggests gives us a matrix as output and describes the complete performance of the model.

# %%
# for Computing confusion matrix to evaluate the accuracy of a classification
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Classification Report
# * Used to measure the quality of predictions from a classification algorithm. How many predictions are True and how many are False. More specifically, True Positives, False Positives, True negatives and False Negatives are used to predict the metrics of a classification report

# %%
# Prints a text report showing the main classification metrics
from sklearn.metrics import classification_report

# %% [markdown]
# ### Mean Squared Error
# * Mean Squared Error(MSE) is quite similar to Mean Absolute Error, the only difference being that MSE takes the average of the square of the difference between the original values and the predicted values.

# %%
# Prints Mean squared error regression loss
from sklearn.metrics import mean_squared_error

# %%
x = pregnancy_details.drop('outcome_pregnancy', axis=1)
y = pregnancy_details['outcome_pregnancy']

# %% [markdown]
# ### 'x' consists of all the data except class label(outcome_pregnancy)
# ### 'y' contains only class lable column i.e., outcome_pregnancy

# %%
#Splitting the dataset content into random train and test subsets
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.3,random_state = 1)
print('Training dataset shape:', xtrain.shape, ytrain.shape)
print('Testing dataset shape:', xtest.shape, ytest.shape)
# Out:
# Training dataset shape: (11260, 18) (11260,)
# Testing dataset shape: (4826, 18) (4826,)

# %% [markdown]
# # Model-1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
class logisticRegression():
    lor = LogisticRegression()
    lor.fit(xtrain,ytrain)
    yp_lr_train = lor.predict(xtrain)
    yp_lr_test = lor.predict(xtest)
    
    def training():
        yp_lr_train = logisticRegression.yp_lr_train
        print("Accuracy of logistic regression for training data:",accuracy_score(ytrain,yp_lr_train))
        print("\nClassification report of logistic regression for training data :\n\n",classification_report(ytrain,yp_lr_train))
        print("Confusion_matrix of logistic regression for training data:\n",confusion_matrix(ytrain,yp_lr_train))
        print('\nMean_squared_error of logistic regression for training data:',mean_squared_error(ytrain,yp_lr_train))

    def testing():
        yp_lr_test = logisticRegression.yp_lr_test
        print("Accuracy of logistic regression for testing data:",accuracy_score(ytest,yp_lr_test))
        print('\nClassification of logistic regression for testing data:\n\n',classification_report(ytest,yp_lr_test))
        print("Confusion_matrix of logistic regression for testing data:\n",confusion_matrix(ytest,yp_lr_test))
        print('Mean_squared_error of logistic regression for testing data:\n',mean_squared_error(ytest,yp_lr_test))
# Out:
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
logisticRegression.training()
# Out:
# Accuracy of logistic regression for training data: 0.9502664298401421
#
# Classification report of logistic regression for training data :
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       559
#            2       0.95      1.00      0.97     10701
#
#     accuracy                           0.95     11260
#    macro avg       0.48      0.50      0.49     11260
# weighted avg       0.90      0.95      0.93     11260
#
# Confusion_matrix of logistic regression for training data:
#  [[    0   559]
#  [    1 10700]]
#
# Mean_squared_error of logistic regression for training data: 0.0497335701598579

# %%
logisticRegression.testing()
# Out:
# Accuracy of logistic regression for testing data: 0.953377538334024
#
# Classification of logistic regression for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       225
#            2       0.95      1.00      0.98      4601
#
#     accuracy                           0.95      4826
#    macro avg       0.48      0.50      0.49      4826
# weighted avg       0.91      0.95      0.93      4826
#
# Confusion_matrix of logistic regression for testing data:
#  [[   0  225]
#  [   0 4601]]
# Mean_squared_error of logistic regression for testing data:
#  0.046622461665975966
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Model-2: Support Vector Machines(SVM)
# * Kernel.1 = Linear
# * Kernel.2 = Sigmoid
# * Kernel.3 = Radial Basis Function(RBF)

# %% [markdown]
# ### Kernel.1 = Linear

# %%
from sklearn import svm
class svc_linear():
    
    lin_svc = svm.SVC(kernel='linear')

    lin_svc.fit(xtrain,ytrain)
    yp_svm_lin_train = lin_svc.predict(xtrain)
    yp_svm_lin_test = lin_svc.predict(xtest)

    def training():
        yp_svm_lin_train = svc_linear.yp_svm_lin_train
        print('Accuracy of Linear-SVM for training data:',accuracy_score(ytrain,yp_svm_lin_train))
        print('\nClassification Report of Linear-SVM for training data:\n\n',classification_report(ytrain,yp_svm_lin_train))
        print('Confusion_matrix of Linear-SVM for training data:\n',confusion_matrix(ytrain,yp_svm_lin_train))
        print('\nMean_squared_error of Linear-SVM for training data:',mean_squared_error(ytrain,yp_svm_lin_train))

    def testing():
        yp_svm_lin_test = svc_linear.yp_svm_lin_test
        print('Accuracy of Linear-SVM for testing data:',accuracy_score(ytest,yp_svm_lin_test))
        print('\nClassification Report of Linear-SVM for testing data:\n\n',classification_report(ytest,yp_svm_lin_test))
        print('Confusion_matrix of Linear-SVM for testing data:\n',confusion_matrix(ytest,yp_svm_lin_test))
        print('\nMean_squared_error of Linear-SVM for testing data:',mean_squared_error(ytest,yp_svm_lin_test))

# %%
svc_linear.training()
# Out:
# Accuracy of Linear-SVM for training data: 0.9503552397868561
#
# Classification Report of Linear-SVM for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       559
#            2       0.95      1.00      0.97     10701
#
#     accuracy                           0.95     11260
#    macro avg       0.48      0.50      0.49     11260
# weighted avg       0.90      0.95      0.93     11260
#
# Confusion_matrix of Linear-SVM for training data:
#  [[    0   559]
#  [    0 10701]]
#
# Mean_squared_error of Linear-SVM for training data: 0.049644760213143874
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc_linear.testing()
# Out:
# Accuracy of Linear-SVM for testing data: 0.953377538334024
#
# Classification Report of Linear-SVM for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       225
#            2       0.95      1.00      0.98      4601
#
#     accuracy                           0.95      4826
#    macro avg       0.48      0.50      0.49      4826
# weighted avg       0.91      0.95      0.93      4826
#
# Confusion_matrix of Linear-SVM for testing data:
#  [[   0  225]
#  [   0 4601]]
#
# Mean_squared_error of Linear-SVM for testing data: 0.046622461665975966
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Kernel.2 = Sigmoid

# %%
class svc_sigmoid():
    sig_svc = svm.SVC(kernel='sigmoid')      
    sig_svc.fit(xtrain,ytrain)
    yp_svm_sig_train = sig_svc.predict(xtrain)
    yp_svm_sig_test = sig_svc.predict(xtest)
    
    def training():
        yp_svm_sig_train = svc_sigmoid.yp_svm_sig_train
        print('Accuracy of Sigmoid-SVM for training data:',accuracy_score(ytrain,yp_svm_sig_train))
        print('\nClassification Report of Sigmoid-SVM for training data:\n\n',classification_report(ytrain,yp_svm_sig_train))
        print('Confusion_matrix of Sigmoid-SVM for training data:\n',confusion_matrix(ytrain,yp_svm_sig_train))
        print('\nMean_squared_error of Sigmoid-SVM for training data:',mean_squared_error(ytrain,yp_svm_sig_train))

    def testing():
        yp_svm_sig_test = svc_sigmoid.yp_svm_sig_test
        print('Accuracy of Sigmoid-SVM for testing data:',accuracy_score(ytest,yp_svm_sig_test))
        print('\nClassification Report of Sigmoid-SVM for testing data:\n\n',classification_report(ytest,yp_svm_sig_test))
        print('Confusion_matrix of Sigmoid-SVM for testing data:\n',confusion_matrix(ytest,yp_svm_sig_test))
        print('\nMean_squared_error of Sigmoid-SVM for testing data:',mean_squared_error(ytest,yp_svm_sig_test))

# %%
svc_sigmoid.training()
# Out:
# Accuracy of Sigmoid-SVM for training data: 0.933303730017762
#
# Classification Report of Sigmoid-SVM for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.08      0.03      0.05       559
#            2       0.95      0.98      0.97     10701
#
#     accuracy                           0.93     11260
#    macro avg       0.52      0.51      0.51     11260
# weighted avg       0.91      0.93      0.92     11260
#
# Confusion_matrix of Sigmoid-SVM for training data:
#  [[   19   540]
#  [  211 10490]]
#
# Mean_squared_error of Sigmoid-SVM for training data: 0.06669626998223802

# %%
svc_sigmoid.testing()
# Out:
# Accuracy of Sigmoid-SVM for testing data: 0.9349357646083714
#
# Classification Report of Sigmoid-SVM for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.07      0.03      0.04       225
#            2       0.95      0.98      0.97      4601
#
#     accuracy                           0.93      4826
#    macro avg       0.51      0.51      0.50      4826
# weighted avg       0.91      0.93      0.92      4826
#
# Confusion_matrix of Sigmoid-SVM for testing data:
#  [[   7  218]
#  [  96 4505]]
#
# Mean_squared_error of Sigmoid-SVM for testing data: 0.06506423539162867

# %% [markdown]
# ### Kernel.2 = Radial Basis Function(RBF)

# %%
class svc_rbf():
    rad_svc = svm.SVC(kernel='rbf')      
    rad_svc.fit(xtrain,ytrain)
    yp_svm_rad_train = rad_svc.predict(xtrain)
    yp_svm_rad_test = rad_svc.predict(xtest)
    
    def training():
        yp_svm_rad_train = svc_rbf.yp_svm_rad_train
        print('Accuracy of RBF-SVM for training data:',accuracy_score(ytrain,yp_svm_rad_train))
        print('\nClassification Report of RBF-SVM for training data:\n\n',classification_report(ytrain,yp_svm_rad_train))
        print('Confusion_matrix of RBF-SVM for training data:\n',confusion_matrix(ytrain,yp_svm_rad_train))
        print('\nMean_squared_error of RBF-SVM for training data:',mean_squared_error(ytrain,yp_svm_rad_train))

    def testing():
        yp_svm_rad_test = svc_rbf.yp_svm_rad_test
        print('Accuracy of RBF-SVM for testing data:',accuracy_score(ytest,yp_svm_rad_test))
        print('\nClassification Report of RBF-SVM for testing data:\n\n',classification_report(ytest,yp_svm_rad_test))
        print('Confusion_matrix of RBF-SVM for testing data:\n',confusion_matrix(ytest,yp_svm_rad_test))
        print('\nMean_squared_error of RBF-SVM for testing data:',mean_squared_error(ytest,yp_svm_rad_test))

# %%
svc_rbf.training()
# Out:
# Accuracy of RBF-SVM for training data: 0.9503552397868561
#
# Classification Report of RBF-SVM for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       559
#            2       0.95      1.00      0.97     10701
#
#     accuracy                           0.95     11260
#    macro avg       0.48      0.50      0.49     11260
# weighted avg       0.90      0.95      0.93     11260
#
# Confusion_matrix of RBF-SVM for training data:
#  [[    0   559]
#  [    0 10701]]
#
# Mean_squared_error of RBF-SVM for training data: 0.049644760213143874
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc_rbf.testing()
# Out:
# Accuracy of RBF-SVM for testing data: 0.953377538334024
#
# Classification Report of RBF-SVM for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       225
#            2       0.95      1.00      0.98      4601
#
#     accuracy                           0.95      4826
#    macro avg       0.48      0.50      0.49      4826
# weighted avg       0.91      0.95      0.93      4826
#
# Confusion_matrix of RBF-SVM for testing data:
#  [[   0  225]
#  [   0 4601]]
#
# Mean_squared_error of RBF-SVM for testing data: 0.046622461665975966
# C:\Users\anike\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Model-3: Decision Tree

# %%
from sklearn import tree
import graphviz

class decisionTree():
    dt = tree.DecisionTreeClassifier(criterion='entropy')
    dt.fit(xtrain,ytrain)
    yp_dt_train = dt.predict(xtrain)
    yp_dt_test = dt.predict(xtest)

    def training():
        yp_dt_train = decisionTree.yp_dt_train
        print('Accuracy of Decision-Tree for training data:',accuracy_score(ytrain,yp_dt_train))
        print('\nClassification Report of Decision Tree for training data:\n\n',classification_report(ytrain,yp_dt_train))
        print('Confusion_matrix of Decision-Tree for training data:\n',confusion_matrix(ytrain,yp_dt_train))
        print('\nMean_squared_error of Decision-Treefor training data:',mean_squared_error(ytrain,yp_dt_train))

    def testing():
        yp_dt_test = decisionTree.yp_dt_test 
        print('Accuracy of Decision-Tree for testing data:',accuracy_score(ytest,yp_dt_test))
        print('\nClassification of Decision-Tree for testing data:\n\n',classification_report(ytest,yp_dt_test)) 
        print('Classification of Decision-Tree for testing data:\n',confusion_matrix(ytest,yp_dt_test))
        print('\nMean_squared_error of Decision-Tree for testing data:',mean_squared_error(ytest,yp_dt_test))
        
    def DT_plot():
        dot_data = tree.export_graphviz(decisionTree.dt, out_file=None,max_depth=5, filled=True, rounded=True, special_characters=True)  
        graph = graphviz.Source(dot_data)  
        #graph.save(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\dt.png")
        return graph

# %%
decisionTree.training()
# Out:
# Accuracy of Decision-Tree for training data: 0.9984014209591474
#
# Classification Report of Decision Tree for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98       559
#            2       1.00      1.00      1.00     10701
#
#     accuracy                           1.00     11260
#    macro avg       0.99      1.00      0.99     11260
# weighted avg       1.00      1.00      1.00     11260
#
# Confusion_matrix of Decision-Tree for training data:
#  [[  556     3]
#  [   15 10686]]
#
# Mean_squared_error of Decision-Treefor training data: 0.0015985790408525756

# %%
decisionTree.testing()
# Out:
# Accuracy of Decision-Tree for testing data: 0.9152507252382925
#
# Classification of Decision-Tree for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.21      0.30      0.25       225
#            2       0.96      0.95      0.96      4601
#
#     accuracy                           0.92      4826
#    macro avg       0.59      0.62      0.60      4826
# weighted avg       0.93      0.92      0.92      4826
#
# Classification of Decision-Tree for testing data:
#  [[  67  158]
#  [ 251 4350]]
#
# Mean_squared_error of Decision-Tree for testing data: 0.08474927476170742

# %% [markdown]
# # Model-4: k-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

class KNN(): 
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(xtrain, ytrain)
    yp_knn_train = knn.predict(xtrain)
    yp_knn_test = knn.predict(xtest)
    
    def knn_plot():
        error_rate = []
        for i in range(1,10):

            knn = KNeighborsClassifier(n_neighbors=i)
            knn.fit(xtrain,ytrain)
            pred_i = knn.predict(xtest)
            error_rate.append(np.mean(pred_i != ytest))

        # Plot for representing the exact value of 'K' to be considered
        plt.figure(figsize=(10,6))
        plt.plot(range(1,10),error_rate,color='g', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10)
        plt.title('Error Rate vs. K Value')
        plt.xlabel('K')
        plt.ylabel('Error Rate')
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\knn_elbow.png")

   
    def training():
        yp_knn_train = KNN.yp_knn_train
        print('Accuracy of K-Nearest Neighbor for training data:',accuracy_score(ytrain,yp_knn_train))
        print('Classification Report of K-Nearest Neighbor for training data:\n\n',classification_report(ytrain,yp_knn_train))
        print('Confusion_matrix of K-Nearest Neighbor for training data:\n',confusion_matrix(ytrain,yp_knn_train))
        print('\nMean_squared_error of K-Nearest Neighbor for training data:',mean_squared_error(ytrain,yp_knn_train))

        
    def testing():
        yp_knn_test = KNN.yp_knn_test
        print('Accuracy of K-Nearest Neighbor for testing data:',accuracy_score(ytest,yp_knn_test))
        print('\nClassification Report of K-Nearest Neighbor for testing data:\n\n',classification_report(ytest,yp_knn_test))
        print('Confusion_matrix of K-Nearest Neighbor for testing data:\n',confusion_matrix(ytest,yp_knn_test)) 
        print('\nMean_squared_error of K-Nearest Neighbor for testing data:',mean_squared_error(ytest,yp_knn_test))

# %%
KNN.training()
# Out:
# Accuracy of K-Nearest Neighbor for training data: 0.9550621669626999
# Classification Report of K-Nearest Neighbor for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.70      0.17      0.27       559
#            2       0.96      1.00      0.98     10701
#
#     accuracy                           0.96     11260
#    macro avg       0.83      0.58      0.62     11260
# weighted avg       0.95      0.96      0.94     11260
#
# Confusion_matrix of K-Nearest Neighbor for training data:
#  [[   94   465]
#  [   41 10660]]
#
# Mean_squared_error of K-Nearest Neighbor for training data: 0.04493783303730018

# %%
KNN.testing()
# Out:
# Accuracy of K-Nearest Neighbor for testing data: 0.949026108578533
#
# Classification Report of K-Nearest Neighbor for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.28      0.06      0.10       225
#            2       0.96      0.99      0.97      4601
#
#     accuracy                           0.95      4826
#    macro avg       0.62      0.53      0.53      4826
# weighted avg       0.92      0.95      0.93      4826
#
# Confusion_matrix of K-Nearest Neighbor for testing data:
#  [[  13  212]
#  [  34 4567]]
#
# Mean_squared_error of K-Nearest Neighbor for testing data: 0.050973891421467056

# %% [markdown]
# # Model-5: Naive Bayes Model

# %%
from sklearn.naive_bayes import MultinomialNB

class naive_bayes():
    NB = MultinomialNB()
    NB.fit(xtrain,ytrain)
    yp_nb_train = NB.predict(xtrain)
    yp_nb_test = NB.predict(xtest)

    def training():
        yp_nb_train = naive_bayes.yp_nb_train
        print('Accuracy of Naive Bayes for training data:',accuracy_score(ytrain,yp_nb_train))
        print('\nClassification Report of Naive Bayes for training data:\n\n',classification_report(ytrain,yp_nb_train))
        print('Confusion_matrix of Naive Bayes for training data:\n',confusion_matrix(ytrain,yp_nb_train))
        print('\nMean_squared_error of Naive Bayes for training data:',mean_squared_error(ytrain,yp_nb_train))

        
    def testing():
        yp_nb_test = naive_bayes.yp_nb_test
        print('Accuracy of Naive Bayes for testing data:',accuracy_score(ytest,yp_nb_test))
        print('\nClassification Report of Naive Bayes for testing data:\n\n',classification_report(ytest,yp_nb_test))
        print('Confusion_matrix of Naive Bayes for testing data:\n',confusion_matrix(ytest,yp_nb_test))
        print('\nMean_squared_error of Naive Bayes for testing data:',mean_squared_error(ytest,yp_nb_test))

# %%
naive_bayes.training()
# Out:
# Accuracy of Naive Bayes for training data: 0.741740674955595
#
# Classification Report of Naive Bayes for training data:
#
#                precision    recall  f1-score   support
#
#            1       0.07      0.37      0.12       559
#            2       0.96      0.76      0.85     10701
#
#     accuracy                           0.74     11260
#    macro avg       0.52      0.57      0.49     11260
# weighted avg       0.91      0.74      0.81     11260
#
# Confusion_matrix of Naive Bayes for training data:
#  [[ 207  352]
#  [2556 8145]]
#
# Mean_squared_error of Naive Bayes for training data: 0.25825932504440496

# %%
naive_bayes.testing()
# Out:
# Accuracy of Naive Bayes for testing data: 0.7281392457521757
#
# Classification Report of Naive Bayes for testing data:
#
#                precision    recall  f1-score   support
#
#            1       0.06      0.36      0.11       225
#            2       0.96      0.75      0.84      4601
#
#     accuracy                           0.73      4826
#    macro avg       0.51      0.55      0.47      4826
# weighted avg       0.92      0.73      0.81      4826
#
# Confusion_matrix of Naive Bayes for testing data:
#  [[  81  144]
#  [1168 3433]]
#
# Mean_squared_error of Naive Bayes for testing data: 0.2718607542478243

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# * Principle Component Analysis(PCA)
# * Forward Feature Selection(Using Random-Forest)
# * Backward Feature Selection(Using Random-Forest)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

class dimensionality_reduction():
    x = pregnancy_details.drop('outcome_pregnancy',axis=1)
    y = pregnancy_details['outcome_pregnancy']
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.3,random_state = 0)
    print('Training dataset shape:', xtrain.shape, ytrain.shape)
    print('Testing dataset shape:', xtest.shape, ytest.shape)
        
    rf = RandomForestClassifier(n_estimators=100, n_jobs=-1)
        
    def PCA():
        pca_data = pregnancy_details.drop('outcome_pregnancy', axis=1) 
        cols = list(pca_data.columns)
        
        # Standardizing data
        scaler = StandardScaler()
        scaler.fit(pca_data)
        scl_data = scaler.transform(pca_data)
        scl_data = pd.DataFrame(data=scl_data)
        
        # Applying PCA on standardized data
        pca = PCA(n_components=14)
        pca.fit(scl_data)
        px = np.arange(1, 15, step=1)
        py = np.cumsum(pca.explained_variance_ratio_) 
        
        # Plotting Elbow to get the no. of components to be considered 
        plt.figure(figsize=(13,6))
        plt.ylim(0.0,1.1)
        plt.plot(px,py,color='g', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10)
        plt.xlabel('Number of Components')
        plt.xticks(np.arange(0, 15, step=1)) #change from 0-based array index to 1-based human-readable label
        plt.ylabel('Cumulative variance (%)')
        plt.title('The number of components needed to explain variance')
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\pca_elbow.png")
        plt.show()
        
        #X is projected on the first principal components previously extracted from a training set
        reduced_pca_data = pca.transform(scl_data)

        fig = plt.figure(figsize=(8,6))
        ax = Axes3D(fig, elev=-150, azim=110)
        ax.scatter(reduced_pca_data[:,0],reduced_pca_data[:,1],reduced_pca_data[:,2],edgecolor='k', s=60, depthshade = True)
        ax.set_title("First three PCA directions")
        ax.set_xlabel("1st eigenvector")
        ax.w_xaxis.set_ticklabels([])
        ax.set_ylabel("2nd eigenvector")
        ax.w_yaxis.set_ticklabels([])
        ax.set_zlabel("3rd eigenvector")
        ax.w_zaxis.set_ticklabels([])
        plt.savefig(r"F:\Sem_3\ML_Project\preg\Visualizations\Bihar\Part_2\pca.png")
        plt.show()
        
        print('PCA Columns:\n',cols)
        print('\nScaled Data Type:\n',type(scl_data))
        print('\nVariance:\n',pca.explained_variance_)
        print('\nVariance Ratios:\n',pca.explained_variance_ratio_)
        
    def ffs():
        sfs1 = sfs(dimensionality_reduction.rf,k_features=3,forward=True,floating=False,verbose=2,scoring='accuracy',cv=5)
        sfs1 = sfs1.fit(dimensionality_reduction.xtrain,dimensionality_reduction.ytrain)
        feat_cols = list(sfs1.k_feature_idx_)
        
        print('\nBest Features according to Forward Feature Selection are:\n',sfs1.k_feature_names_)
        print('\nScore:',sfs1.k_score_)
        
    
    def bfs():
        bfs1 = sfs(dimensionality_reduction.rf,k_features=3,forward=False,floating=False,verbose=2,scoring='accuracy',cv=5)
        bfs1 = bfs1.fit(dimensionality_reduction.xtrain,dimensionality_reduction.ytrain)
        feat_cols = list(bfs1.k_feature_idx_)
        
        print('Best Feature according to Backward Feature Selection are:\n',bfs1.k_feature_names_)
        print('\nScore:',bfs1.k_score_)
# Out:
# Training dataset shape: (11260, 18) (11260,)
# Testing dataset shape: (4826, 18) (4826,)

# %%
dimensionality_reduction.PCA()
# Out:
# PCA Columns:
#  ['mother_age_when_baby_was_born', 'fp_method_used', 'symptoms_pertaining_illness', 'diagnosed_for', 'regular_treatment', 'chew', 'smoke', 'alcohol', 'drinking_water_source', 'kitchen_availability', 'is_washing_machine', 'is_bicycle', 'is_scooter', 'is_sewing_machine', 'ever_conceived', 'no_of_times_conceived', 'age_at_first_conception', 'delivered_any_baby']
#
# Scaled Data Type:
#  <class 'pandas.core.frame.DataFrame'>
#
# Variance:
#  [1.85589875 1.50703317 1.48898023 1.26754948 1.07499044 1.02025518
#  0.99477208 0.97886914 0.93619381 0.8951079  0.86167554 0.8068468
#  0.79219793 0.77439799]
#
# Variance Ratios:
#  [0.11598646 0.09418372 0.09305548 0.07921692 0.06718273 0.06376198
#  0.06216939 0.06117552 0.05850848 0.05594077 0.05385137 0.05042479
#  0.04950929 0.04839687]

# %%
dimensionality_reduction.bfs()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   38.4s finished
#
# [2021-05-11 09:17:39] Features: 17/3 -- score: 0.9522202486678507[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   34.5s finished
#
# [2021-05-11 09:18:14] Features: 16/3 -- score: 0.9523090586145649[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   33.1s finished
#
# [2021-05-11 09:18:47] Features: 15/3 -- score: 0.952397868561279[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   29.2s finished
#
# [2021-05-11 09:19:16] Features: 14/3 -- score: 0.952841918294849[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   27.1s finished
#
# [2021-05-11 09:19:43] Features: 13/3 -- score: 0.952486678507993[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   25.4s finished
#
# [2021-05-11 09:20:09] Features: 12/3 -- score: 0.9521314387211369[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   23.4s finished
#
# [2021-05-11 09:20:32] Features: 11/3 -- score: 0.9519538188277087[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   21.1s finished
#
# [2021-05-11 09:20:54] Features: 10/3 -- score: 0.9515097690941385[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   18.8s finished
#
# [2021-05-11 09:21:12] Features: 9/3 -- score: 0.9502664298401422[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   16.6s finished
#
# [2021-05-11 09:21:29] Features: 8/3 -- score: 0.9508880994671403[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   14.6s finished
#
# [2021-05-11 09:21:44] Features: 7/3 -- score: 0.9496447602131438[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.0s finished
#
# [2021-05-11 09:21:57] Features: 6/3 -- score: 0.947246891651865[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   11.2s finished
#
# [2021-05-11 09:22:08] Features: 5/3 -- score: 0.9466252220248668[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.7s finished
#
# [2021-05-11 09:22:17] Features: 4/3 -- score: 0.9466252220248668[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# Best Feature according to Backward Feature Selection are:
#  ('fp_method_used', 'symptoms_pertaining_illness', 'kitchen_availability')
#
# Score: 0.9494671403197158
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.8s finished
#
# [2021-05-11 09:22:24] Features: 3/3 -- score: 0.9494671403197158

# %%
dimensionality_reduction.ffs()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   27.3s finished
#
# [2021-05-11 09:22:51] Features: 1/3 -- score: 0.9506216696269982[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   25.5s finished
#
# [2021-05-11 09:23:17] Features: 2/3 -- score: 0.9506216696269982[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# Best Features according to Forward Feature Selection are:
#  ('mother_age_when_baby_was_born', 'smoke', 'alcohol')
#
# Score: 0.9506216696269982
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   24.4s finished
#
# [2021-05-11 09:23:41] Features: 3/3 -- score: 0.9506216696269982
